# %%
import pandas as pd

# %%
df = pd.read_table('emp_qiime_mapping_qc_filtered.tsv', sep='\t', index_col=0)
print(df)
df.dropna(axis=0, inplace=True, subset=['ph'])
df = df[df.env_material == 'soil']
df
df = df[['Description', 'title', 'latitude_deg', 'longitude_deg', 'country','env_biome', 'ph']]
df.dropna(inplace=True)
# Out:
#                                                    BarcodeSequence  \
# #SampleID
# 550.L1S1.s.1.sequence                                 AACGCACGCTAG
# 550.L1S10.s.1.sequence                                ACAGACCACTCA
# 550.L1S100.s.1.sequence                               ATGCACTGGCGA
# 550.L1S101.s.1.sequence                               ATTATCGTGCAC
# 550.L1S102.s.1.sequence                               CACGACAGGCTA
# 550.L1S103.s.1.sequence                               CAGATACACTTC
# 550.L1S104.s.1.sequence                               CAGTGTCAGGAC
# 550.L1S105.s.1.sequence                               AGTGCGATGCGT
# 550.L1S106.s.1.sequence                               ATACTCACTCAG
# 550.L1S107.s.1.sequence                               ATCGCTCGAGGA
# 550.L1S108.s.1.sequence                               ATGCAGCTCAGT
# 550.L1S109.s.1.sequence                               ATTCTGTGAGCG
# 550.L1S11.s.1.sequence                                ACCAGCGACTAG
# ...

# %%
df.to_csv('filtered_emp_map.tsv', sep='\t')

# %%
df
# Out:
#                                                                       Description  \
# #SampleID
# 632.Agricultural.soil.soy                        Agricultural soil - soy, Ontario
# 632.Agricultural.soil.wheat                    Agricultural soil - wheat, Ontario
# 632.Arctic.Tundra.1                                 Arctic Tundra 1, Darring Lake
# 632.Arctic.Tundra.2                                               Arctic Tundra 2
# 632.Boreal.coniferous.forest                    Boreal coniferous forest, Alberta
# 632.Northern.peatlands                               Northern peatlands, Old Crow
# 632.Tar.sand.1                                                Tar sand 1, Alberta
# 632.Tar.sand.2                                                Tar sand 2, Alberta
# 632.Temperate.deciduous.forest                Temperate deciduous forest, Ontario
# 632.Temperate.rain.forest                 Temperate rain forest, British Columbia
# ...

# %%
6.
# Out:
# 6.0
